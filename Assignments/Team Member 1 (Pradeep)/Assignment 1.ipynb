# %%
# !pip install -q kaggle # connecting kaggle

# %%
# !mkdir ~/.kaggle    # create a kaggle directory
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !cp kaggle.json ~/.kaggle # copying json file to folder

# %%
# !kaggle datasets download -d mohamedafsal007/house-price-dataset-of-india
# Out:
# ...
# house-price-dataset-of-india.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip /content/house-price-dataset-of-india.zip
# Out:
# Archive:  /content/house-price-dataset-of-india.zip
# replace House Price India.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: n

# %%
import pandas as pd

# %%
data=pd.read_csv("House Price India.csv")

# %%
data.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
data.columns
# Out:
# Index(['id', 'Date', 'number of bedrooms', 'number of bathrooms',
#        'living area', 'lot area', 'number of floors', 'waterfront present',
#        'number of views', 'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Postal Code', 'Lattitude',
#        'Longitude', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
import seaborn as sns

# %% [markdown]
# # Bivariate Analysis

# %%
sns.lineplot(x=data['number of bedrooms'],y=data['Price'])
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='Price'>

# %%
sns.scatterplot(x=data['Lattitude'],y=data['Longitude'])
# Out:
# <Axes: xlabel='Lattitude', ylabel='Longitude'>

# %%
sns.scatterplot(x=data['number of bedrooms'],y=data['number of bathrooms'])
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='number of bathrooms'>

# %% [markdown]
# # Univariate Analysis

# %%
sns.distplot(data['Price'])
# Out:
# <ipython-input-27-049e7ab17fe1>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(data[['Date', 'number of bedrooms', 'number of bathrooms',
       'living area', 'lot area']])

# %% [markdown]
# # Missing Value Handling - no missing values

# %%
data.isnull()
# Out:
#           id   Date  number of bedrooms  number of bathrooms  living area  \
# 0      False  False               False                False        False
# 1      False  False               False                False        False
# 2      False  False               False                False        False
# 3      False  False               False                False        False
# 4      False  False               False                False        False
# ...      ...    ...                 ...                  ...          ...
# 14615  False  False               False                False        False
# 14616  False  False               False                False        False
# 14617  False  False               False                False        False
# 14618  False  False               False                False        False
# 14619  False  False               False                False        False
#
#        lot area  number of floors  waterfront present  number of views  \
# ...
